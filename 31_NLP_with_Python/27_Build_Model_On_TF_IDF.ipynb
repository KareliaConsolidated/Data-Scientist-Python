# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('Data/X_train.csv')
X_test = pd.read_csv('Data/X_test.csv')
y_train = pd.read_csv('Data/y_train.csv')
y_test = pd.read_csv('Data/y_test.csv')

X_train.head()
# Out:
# G:\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
#                                           clean_text
# 0  ['tomorrow', 'going', 'theatre', 'come', 'wher...
# 1  ['', 'ltgt', 'mins', 'stop', 'somewhere', 'fir...
# 2  ['come', 'room', 'cannot', 'come', 'house', 'c...
# 3                                        ['holding']
# 4                    ['pls', 'call', 'da', 'happen']

# %% [markdown]
# ### Create TFIDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and the use that trained vectorizer to the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'tomorrow': 7276,
#  'going': 3281,
#  'theatre': 7134,
#  'come': 1993,
#  'wherever': 7806,
#  'call': 1671,
#  'tell': 7068,
#  'ltgt': 4458,
#  'mins': 4715,
#  'stop': 6803,
#  'somewhere': 6603,
#  'first': 2979,
#  'room': 6100,
#  'cannot': 1714,
#  'house': 3647,
#  'cos': 2110,
#  'still': 6791,
#  'messy': 4678,
#  'haha': 3414,
#  'holding': 3594,
#  'pls': 5528,
#  'da': 2225,
#  'happen': 3444,
#  'interflora': 3857,
#  'åòits': 8137,
#  'late': 4222,
#  'order': 5246,
#  'flowers': 3015,
#  'christmas': 1901,
#  '0800': 36,
#  '505060': 583,
#  'place': 5496,
#  'midnight': 4690,
#  'like': 4315,
#  'cheap': 1832,
#  'happy': 3453,
#  'splash': 6689,
#  'wine': 7843,
#  'makes': 4530,
#  'feel': 2917,
#  'better': 1390,
#  'wot': 7936,
#  'thout': 7180,
#  'gonna': 3291,
#  'txt': 7412,
#  'bak': 1271,
#  'luv': 4476,
#  'private': 5697,
#  '2004': 376,
#  'account': 836,
#  'statement': 6760,
#  '07742676969': 21,
#  'shows': 6419,
#  '786': 669,
#  'unredeemed': 7491,
#  'bonus': 1481,
#  'points': 5556,
#  'claim': 1912,
#  '08719180248': 140,
#  'identifier': 3738,
#  'code': 1968,
#  '45239': 545,
#  'expires': 2830,
#  'made': 4510,
#  'payments': 5392,
#  'dont': 2518,
#  'much': 4858,
#  'sorry': 6625,
#  'would': 7940,
#  'want': 7696,
#  'fedex': 2916,
#  'way': 7728,
#  'free': 3090,
#  'message': 4666,
#  'activate': 854,
#  '500': 580,
#  'text': 7096,
#  'messages': 4671,
#  'replying': 5989,
#  'word': 7906,
#  'terms': 7085,
#  'conditions': 2046,
#  'visit': 7623,
#  'www07781482378com': 7968,
#  'yep': 8058,
#  'dereks': 2370,
#  'see': 6269,
#  'sunday': 6907,
#  'lt3': 4454,
#  'havent': 3471,
#  'got': 3315,
#  'topic': 7300,
#  'yet': 8074,
#  'rite': 6075,
#  'bus': 1632,
#  'september': 6309,
#  'hi': 3542,
#  'mate': 4582,
#  'rv': 6145,
#  'hav': 3469,
#  'nice': 4993,
#  'hol': 3590,
#  'say': 6211,
#  'hello': 3509,
#  'coz': 2139,
#  'havenåõt': 3473,
#  'sent': 6302,
#  'ages': 922,
#  'started': 6750,
#  'driving': 2570,
#  'stay': 6765,
#  'roadsrvx': 6080,
#  'probably': 5706,
#  'everybodys': 2781,
#  'done': 2517,
#  'around': 1136,
#  'right': 6056,
#  'im': 3756,
#  'wearing': 7739,
#  'blue': 1465,
#  'shirt': 6377,
#  'black': 1432,
#  'pants': 5333,
#  'urgent': 7524,
#  'mobile': 4764,
#  'awarded': 1236,
#  '2000': 373,
#  'caller': 1684,
#  'prize': 5700,
#  '020903': 8,
#  '2nd': 441,
#  'attempt': 1193,
#  'contact': 2071,
#  '08718729755': 134,
#  'box95qu': 1526,
#  'none': 5052,
#  'thats': 7128,
#  'happening': 3447,
#  'til': 7212,
#  'get': 3224,
#  'though': 7176,
#  'funny': 3158,
#  'kgive': 4093,
#  'back': 1262,
#  'thanks': 7113,
#  'think': 7160,
#  'away': 1237,
#  'trek': 7354,
#  'long': 4392,
#  'family': 2878,
#  'town': 7320,
#  'ok': 5173,
#  'ur': 7521,
#  'home': 3602,
#  'half': 3423,
#  'hour': 3644,
#  'ooooooh': 5216,
#  'forgot': 3056,
#  'yoville': 8111,
#  'phone': 5453,
#  'okay': 5174,
#  'lor': 4406,
#  'let': 4283,
#  'us': 7534,
#  'go': 3266,
#  'ah': 929,
#  'know': 4147,
#  'later': 4226,
#  'drop': 2574,
#  'cards': 1728,
#  'box': 1512,
#  '22': 390,
#  '146tf150p': 293,
#  'leave': 4257,
#  'need': 4949,
#  'ask': 1162,
#  'ofcourse': 5144,
#  'also': 991,
#  'upload': 7508,
#  'songs': 6610,
#  'sun': 6906,
#  'thk': 7167,
#  'mayb': 4599,
#  'dun': 2601,
#  'anythin': 1062,
#  'book': 1484,
#  'lesson': 4281,
#  'pilates': 5480,
#  'orchard': 5245,
#  'mrt': 4836,
#  'noe': 5035,
#  'hor': 3628,
#  'forwarded': 3070,
#  '448712404000please': 538,
#  '08712404000': 94,
#  'immediately': 3766,
#  'waiting': 7673,
#  'cock': 1966,
#  'hubbys': 3680,
#  'real': 5877,
#  'man': 4537,
#  'satisfy': 6199,
#  'wife': 7826,
#  '89938': 762,
#  'strings': 6833,
#  'action': 852,
#  'end': 2700,
#  'rec': 5898,
#  '150ea': 297,
#  'otbox': 5262,
#  '731': 662,
#  'la1': 4180,
#  '7ws': 680,
#  'rose': 6104,
#  'redred': 5928,
#  'bloodblood': 1458,
#  'heartheart': 3495,
#  'send': 6293,
#  'tis': 7229,
#  'friends': 3116,
#  'including': 3789,
#  '1u': 365,
#  'poor': 5579,
#  'relation': 5948,
#  '2u': 452,
#  'support': 6925,
#  '3u': 512,
#  'frnd': 3123,
#  'many': 4552,
#  '4some1': 570,
#  'luvs': 4477,
#  'some1': 6587,
#  'praying': 5643,
#  'god': 3272,
#  'marry': 4568,
#  'try': 7374,
#  'ran': 5841,
#  'younger': 8100,
#  'make': 4529,
#  'pretty': 5676,
#  'babies': 1256,
#  'together': 7259,
#  'helloooo': 3512,
#  'wake': 7675,
#  'sweet': 6960,
#  'morning': 4810,
#  'welcomes': 7770,
#  'enjoy': 2715,
#  'day': 2277,
#  'full': 3148,
#  'joy': 4021,
#  'gud': 3384,
#  'mrng': 4835,
#  'ard': 1114,
#  '515': 588,
#  'dat': 2264,
#  'cheers': 1846,
#  'card': 1725,
#  'time': 7215,
#  'year': 8052,
#  'already': 985,
#  'okok': 5180,
#  'okthenwhats': 5183,
#  'todays': 7256,
#  'plan': 5502,
#  'comes': 1996,
#  'holiday': 3596,
#  'coming': 2001,
#  'dont4get2text': 2519,
#  'number': 5106,
#  'meet': 4624,
#  'lunch': 4470,
#  'la': 4179,
#  'hope': 3622,
#  'mad': 4507,
#  'gudnitetcpractice': 3386,
#  'okmail': 5179,
#  'dear': 2298,
#  'dave': 2273,
#  'final': 2957,
#  'notice': 5074,
#  'collect': 1979,
#  'tenerife': 7080,
#  '5000': 581,
#  'cash': 1752,
#  'award': 1235,
#  '09061743806': 182,
#  'landline': 4202,
#  'tcs': 7040,
#  'sae': 6157,
#  'box326': 1517,
#  'cw25wx': 2221,
#  '150ppm': 315,
#  'fear': 2912,
#  'fainting': 2864,
#  'housework': 3651,
#  'quick': 5807,
#  'cuppa': 2199,
#  'take': 6995,
#  'noon': 5054,
#  'hospital': 3634,
#  'return': 6037,
#  'evening': 2774,
#  'ki': 4095,
#  'didt': 2415,
#  'youkwhere': 8095,
#  'chechi': 1836,
#  'talk': 7002,
#  'wud': 7964,
#  'never': 4976,
#  'mind': 4705,
#  'miss': 4731,
#  'wil': 7832,
#  'really': 5885,
#  'hurt': 3705,
#  'wen': 7775,
#  'amp': 1012,
#  'care': 1729,
#  'nothis': 5073,
#  'kallis': 4053,
#  'groundamla': 3368,
#  'durban': 2604,
#  'yeah': 8050,
#  'probs': 5714,
#  'last': 4219,
#  'night': 5001,
#  'obviously': 5134,
#  'catching': 1764,
#  'speak': 6658,
#  'soon': 6614,
#  'ha': 3407,
#  'wouldnt': 7942,
#  'didnt': 2413,
#  'read': 5871,
#  'anything': 1063,
#  'seemed': 6274,
#  'judgementali': 4027,
#  'save': 6206,
#  'fridays': 3113,
#  'pub': 5764,
#  'shall': 6344,
#  'exe': 2814,
#  'mail': 4520,
#  'id': 3731,
#  'objection': 5131,
#  'bf': 1395,
#  'hahahause': 3415,
#  'brain': 1536,
#  'put': 5786,
#  'sign': 6440,
#  'choose': 1893,
#  'pin': 5485,
#  'show': 6411,
#  'yes': 8060,
#  'innocent': 3832,
#  'fun': 3151,
#  'kothi': 4165,
#  'print': 5689,
#  'marandratha': 4556,
#  'network': 4972,
#  'operator': 5225,
#  'service': 6316,
#  'cs': 2184,
#  '80488biz': 692,
#  'dislikes': 2467,
#  'bed': 1344,
#  'lost': 4414,
#  '10': 238,
#  'kilos': 4109,
#  'today': 7253,
#  'congratulations': 2058,
#  'cd': 1775,
#  'vouchers': 7646,
#  '125gift': 277,
#  'guaranteed': 3383,
#  'entry': 2733,
#  '100': 239,
#  'wkly': 7876,
#  'draw': 2551,
#  'music': 4881,
#  '87066': 736,
#  'tncs': 7246,
#  'wwwldewcom1win150ppmx3age16': 7987,
#  'lol': 4385,
#  'diet': 2419,
#  'everyday': 2783,
#  'cheat': 1834,
#  'anyway': 1067,
#  'meant': 4613,
#  'fatty': 2902,
#  'oh': 5166,
#  'yah': 8037,
#  'cancel': 1707,
#  'leh': 4269,
#  'vodafone': 7634,
#  'numbers': 5108,
#  'ending': 2702,
#  '4882': 550,
#  'selected': 6281,
#  'receive': 5903,
#  '350': 483,
#  'matches': 4581,
#  '09064019014': 196,
#  'wont': 7900,
#  'wats': 7726,
#  'wit': 7863,
#  'guys': 3400,
#  'buy': 1643,
#  'newspapers': 4987,
#  'ooh': 5213,
#  '4got': 561,
#  'start': 6749,
#  'belly': 1369,
#  'dancing': 2245,
#  'moseley': 4814,
#  'weds': 7751,
#  '630': 624,
#  'join': 4002,
#  'cafe': 1661,
#  'realy': 5886,
#  'sorryi': 6626,
#  'recognise': 5916,
#  'confused': 2055,
#  'please': 5520,
#  'watching': 7719,
#  'tv': 7401,
#  'mm': 4751,
#  'enough': 2722,
#  'ew': 2800,
#  'one': 5197,
#  'freemsg': 3096,
#  'ready': 5875,
#  'horny': 3630,
#  'live': 4351,
#  'love': 4428,
#  'sex': 6327,
#  'games': 3176,
#  'netcollex': 4969,
#  'ltd': 4455,
#  '08700621170150p': 59,
#  'per': 5415,
#  'msg': 4839,
#  'reply': 5987,
#  'recpt': 5924,
#  '13': 283,
#  'ordered': 5247,
#  'ringtone': 6064,
#  'processed': 5716,
#  'ive': 3930,
#  'trying': 7376,
#  'reach': 5866,
#  'without': 7867,
#  'success': 6879,
#  '09066612661': 220,
#  'luxury': 4479,
#  'canary': 1706,
#  'islands': 3903,
#  'await': 1232,
#  'collection': 1982,
#  '20m12aq': 381,
#  '16': 329,
#  'ûï': 8147,
#  'wipro': 7852,
#  'interview': 3862,
#  'glad': 3255,
#  'went': 7777,
#  'well': 7771,
#  '11': 259,
#  'plenty': 5525,
#  'claire': 1915,
#  'goes': 3277,
#  'work': 7912,
#  'member': 4641,
#  'said': 6164,
#  'aunt': 1209,
#  'flow': 3013,
#  'months': 4802,
#  'cause': 1766,
#  'developed': 2392,
#  'ovarian': 5286,
#  'cysts': 2224,
#  'bc': 1320,
#  'shrink': 6422,
#  'engalnd': 2711,
#  'telly': 7071,
#  'decided': 2312,
#  'watch': 7716,
#  'mia': 4686,
#  'elliot': 2681,
#  'kissing': 4120,
#  'damn': 2240,
#  'yup': 8122,
#  '32000': 476,
#  'maybe': 4600,
#  'even': 2773,
#  '1000': 240,
#  '18': 334,
#  'legitimat': 4267,
#  'efreefone': 2655,
#  'wat': 7715,
#  'boye': 1529,
#  'changed': 1806,
#  'goin': 3279,
#  'workout': 7917,
#  'muz': 4888,
#  'lose': 4409,
#  'fats': 2901,
#  'hasnt': 3462,
#  'pattern': 5381,
#  'recently': 5908,
#  'crap': 2148,
#  'weekends': 7757,
#  'look': 4396,
#  'frying': 3135,
#  'pan': 5325,
#  'case': 1751,
#  'perhaps': 5421,
#  'silly': 6448,
#  'likely': 4317,
#  'yar': 8043,
#  'keep': 4074,
#  'raining': 5829,
#  'non': 5050,
#  'wan': 7691,
#  'elsewhere': 2684,
#  'worry': 7928,
#  'big': 1403,
#  'lambu': 4197,
#  'ji': 3987,
#  'vl': 7631,
#  'cometil': 1997,
#  'batchlor': 1303,
#  'party': 5362,
#  'welcome': 7769,
#  'select': 6280,
#  'o2': 5124,
#  'added': 865,
#  'benefits': 1379,
#  'specially': 6663,
#  'trained': 7329,
#  'advisors': 893,
#  'dialling': 2404,
#  '402': 522,
#  'course': 2132,
#  'stink': 6793,
#  'cant': 1716,
#  'display': 2470,
#  'texts': 7106,
#  'ignoring': 3748,
#  'shopping': 6396,
#  'somebody': 6588,
#  'andros': 1028,
#  'steal': 6773,
#  'ice': 3727,
#  'money': 4791,
#  'worries': 7927,
#  'things': 7159,
#  'due': 2596,
#  'several': 6326,
#  'outstanding': 5284,
#  'invoices': 3877,
#  'two': 7411,
#  'three': 7183,
#  'ago': 926,
#  'mums': 4872,
#  'present': 5667,
#  'ar': 1110,
#  'turns': 7399,
#  'stereo': 6780,
#  'mi': 4685,
#  'unknown': 7484,
#  'album': 955,
#  'dahe': 2234,
#  'stupid': 6858,
#  'daalways': 2227,
#  'sending': 6296,
#  'thisdon': 7166,
#  'believe': 1365,
#  'messagepandy': 4670,
#  'mental': 4650,
#  'mu': 4857,
#  'sorting': 6630,
#  'narcotics': 4918,
#  'situation': 6479,
#  'great': 3347,
#  'beautiful': 1337,
#  'new': 4979,
#  'offer': 5147,
#  'double': 2531,
#  'best': 1382,
#  'orange': 5242,
#  'tariffs': 7017,
#  'latest': 4228,
#  'camera': 1700,
#  'phones': 5456,
#  'mobileupd8': 4768,
#  '08000839402': 39,
#  '2stoptxt': 451,
#  'might': 4692,
#  'changes': 1807,
#  'report': 5991,
#  'previous': 5678,
#  'reaching': 5869,
#  'pathaya': 5379,
#  'enketa': 2719,
#  'maraikara': 4555,
#  'pa': 5307,
#  'ltdecimalgt': 4456,
#  'pm': 5534,
#  'vikkyim': 7611,
#  'otside': 5266,
#  'nw': 5116,
#  'il': 3752,
#  'tht': 7195,
#  'nightswe': 5007,
#  'nt': 5098,
#  'staying': 6768,
#  'port': 5589,
#  'step': 6778,
#  'liaotoo': 4292,
#  'ex': 2801,
#  'ill': 3754,
#  'sch': 6225,
#  'fr': 3079,
#  '46': 546,
#  'haf': 3413,
#  'blastin': 1440,
#  'tsunamis': 7384,
#  'occur': 5137,
#  'rajnikant': 5836,
#  'stopped': 6808,
#  'swimming': 6967,
#  'indian': 3803,
#  'oceand': 5139,
#  'customer': 2210,
#  'announcement': 1038,
#  'tried': 7357,
#  'delivery': 2347,
#  'unable': 7450,
#  '07090298926': 15,
#  'reschedule': 6000,
#  'ref9307622': 5932,
#  'congrats': 2057,
#  'wanted': 7698,
#  'score': 6230,
#  'relax': 5951,
#  'motivating': 4820,
#  'sharing': 6353,
#  'babe': 1253,
#  'fucking': 3140,
#  'fuck': 3137,
#  'good': 3293,
#  'hear': 3488,
#  'voice': 7636,
#  'crave': 2152,
#  'adore': 880,
#  'ahmad': 933,
#  'kisses': 4119,
#  'jay': 3961,
#  'snickering': 6565,
#  'tells': 7070,
#  'totally': 7313,
#  'chords': 1896,
#  'taking': 7000,
#  'part': 5355,
#  'survey': 6942,
#  'yesterday': 8073,
#  'use': 7538,
#  'however': 3655,
#  'wish': 7857,
#  'txts': 7419,
#  '80160': 688,
#  'tc': 7037,
#  'wwwtxt43com': 8004,
#  '150p': 300,
#  'understand': 7463,
#  'important': 3771,
#  'poorly': 5580,
#  'thought': 7177,
#  'punishment': 5774,
#  'face': 2852,
#  'worst': 7933,
#  'thing': 7157,
#  'ever': 2778,
#  'happened': 3446,
#  'brb': 1544,
#  'kill': 4105,
#  'tat': 7023,
#  'yijue': 8079,
#  'tot': 7311,
#  'group': 3369,
#  'meeting': 4627,
#  'mah': 4518,
#  'askin': 1165,
#  'leaving': 4259,
#  'earlier': 2617,
#  'walk': 7678,
#  'far': 2889,
#  'interested': 3855,
#  'multiply': 4866,
#  'independently': 3801,
#  'count': 2124,
#  'decimal': 2314,
#  'division': 2477,
#  'push': 5783,
#  'places': 5500,
#  'showed': 6412,
#  'hey': 3536,
#  'kate': 4065,
#  'give': 3250,
#  'youve': 8108,
#  'minute': 4720,
#  'ni8swt': 4991,
#  'drmstake': 2573,
#  'called': 1683,
#  'mom': 4783,
#  'instead': 3848,
#  'multimedia': 4865,
#  'email': 2687,
#  'beauty': 1339,
#  'life': 4301,
#  'next': 4988,
#  'second': 6256,
#  'hides': 3546,
#  'thousands': 7179,
#  'secrets': 6262,
#  'every': 2779,
#  'wonderful': 7897,
#  'n8': 4897,
#  'hmmmbut': 3578,
#  'sunshine': 6913,
#  'hols': 3600,
#  'med': 4619,
#  'stamped': 6739,
#  'self': 6283,
#  'address': 869,
#  'envelope': 2736,
#  'drinks': 2566,
#  'uk': 7439,
#  'po': 5536,
#  '113': 261,
#  'bray': 1543,
#  'wicklow': 7822,
#  'eire': 2669,
#  'quiz': 5813,
#  'starts': 6754,
#  'saturday': 6202,
#  'unsub': 7496,
#  'izzit': 3933,
#  'heavily': 3498,
#  'outside': 5282,
#  'parents': 5347,
#  'kidz': 4104,
#  'colleagues': 1978,
#  'screaming': 6242,
#  'surprise': 6939,
#  'sofa': 6577,
#  'naked': 4905,
#  'goodno': 3304,
#  'problembut': 5709,
#  'little': 4350,
#  'experience': 2826,
#  'american': 1002,
#  'fine': 2963,
#  'gr8': 3326,
#  'school': 6227,
#  'plans': 5508,
#  'completely': 2023,
#  'formclark': 3063,
#  'utter': 7555,
#  'waste': 7712,
#  'cedar': 1778,
#  'key': 4087,
#  'tho': 7172,
#  'hoping': 3627,
#  'enjoyed': 2716,
#  'game': 3175,
#  'touch': 7314,
#  'fondly': 3032,
#  'bein': 1364,
#  'thot': 7174,
#  'week': 7754,
#  'abiola': 809,
#  'callsmessagesmissed': 1693,
#  'calls': 1692,
#  'sitting': 6478,
#  'everyone': 2784,
#  'suite': 6894,
#  'shower': 6413,
#  'darren': 2261,
#  'pick': 5465,
#  'oso': 5261,
#  'sian': 6429,
#  'tmr': 7242,
#  'lect': 4260,
#  'mmmmm': 4754,
#  'sooooo': 6621,
#  'words': 7909,
#  'mmmm': 4753,
#  'lion': 4333,
#  'devouring': 2396,
#  'kiss': 4118,
#  'across': 848,
#  'sea': 6250,
#  'carlos': 1740,
#  'says': 6215,
#  'set': 6319,
#  'crucify': 2178,
#  'told': 7265,
#  'bring': 1568,
#  'beneath': 1377,
#  'pale': 5323,
#  'moon': 4804,
#  'light': 4311,
#  'someone': 6590,
#  'dreams': 2556,
#  'true': 7366,
#  'goodnite': 3303,
#  'dinner': 2440,
#  'moved': 4825,
#  'in2': 3783,
#  'cud': 2190,
#  'santha': 6184,
#  'num': 5105,
#  'corrct': 2104,
#  'dane': 2246,
#  'wah': 7664,
#  'okie': 5178,
#  'unlimited': 7486,
#  'whats': 7794,
#  'wanna': 7694,
#  'sure': 6934,
#  'knocking': 4146,
#  'door': 2523,
#  'finish': 2968,
#  'saying': 6214,
#  'mushy': 4880,
#  'embarrassed': 2691,
#  'aight': 939,
#  'youre': 8102,
#  'swing': 6968,
#  'darling': 2258,
#  'weeks': 7759,
#  'tb': 7035,
#  'xxx': 8028,
#  'std': 6770,
#  'chgs': 1862,
#  '150': 295,
#  'rcv': 5863,
#  'dis': 2452,
#  'sweater': 6958,
#  'mango': 4549,
#  'size': 6484,
#  'irritating': 3895,
#  'bathroom': 1307,
#  'sup': 6915,
#  'sms': 6554,
#  'chat': 1828,
#  'mr': 4833,
#  'view': 7608,
#  'couple': 2129,
#  'gays': 3193,
#  'mean': 4608,
#  'bell': 1367,
#  'ya': 8035,
#  'restrict': 6026,
#  'eating': 2634,
#  'likes': 4318,
#  'days': 2280,
#  'loud': 4423,
#  'scream': 6240,
#  'minutes': 4721,
#  'gyno': 3406,
#  'shoving': 6410,
#  'belong': 1370,
#  'thursday': 7199,
#  'alone': 982,
#  'argh': 1121,
#  '3g': 499,
#  'spotty': 6708,
#  'remember': 5961,
#  'research': 6001,
#  'province': 5754,
#  'sterling': 6782,
#  'problemfree': 5710,
#  'looked': 4398,
#  'wuld': 7965,
#  'baby': 1257,
#  'mite': 4744,
#  'break': 1546,
#  'donåõt': 2521,
#  'crazy': 2154,
#  'everyboy': 2782,
#  'needs': 4955,
#  'lady': 4191,
#  'xxxxxxxx': 8032,
#  'cup': 2198,
#  'rajini': 5834,
#  'car': 1724,
#  'park': 5351,
#  'must': 4883,
#  'huh': 3686,
#  'yoga': 8084,
#  'basic': 1298,
#  'legs': 4268,
#  'neck': 4946,
#  'killing': 4107,
#  'amigos': 1004,
#  'burn': 1627,
#  'could': 2120,
#  'fantastic': 2887,
#  'chance': 1803,
#  'bigger': 1404,
#  'lift': 4308,
#  'losing': 4412,
#  'person': 5430,
#  'die': 2416,
#  'natalie': 4923,
#  '20f': 380,
#  'inviting': 3876,
#  'friend': 3114,
#  'yes165': 8061,
#  'no165': 5025,
#  'wwwsmsacunatalie2k9': 7998,
#  '62468': 623,
#  'wishing': 7860,
#  'merry': 4662,
#  'mas': 4572,
#  'advance': 887,
#  'wow': 7944,
#  'sooo': 6619,
#  'barely': 1290,
#  'stand': 6741,
#  'wonder': 7896,
#  'fix': 2985,
#  'teethif': 7062,
#  'asapok': 1154,
#  'oops': 5217,
#  'bit': 1426,
#  'princess': 5688,
#  'catch': 1762,
#  'strong': 6837,
#  'hands': 3436,
#  'stuck': 6843,
#  'dads': 2233,
#  'tonight': 7286,
#  'dude': 2593,
#  'longer': 4393,
#  'pisces': 5488,
#  'aquarius': 1109,
#  'whatever': 7793,
#  'sleepingand': 6507,
#  'surfing': 6936,
#  'sundayish': 6908,
#  'bold': 1474,
#  'torch': 7306,
#  '2bold': 420,
#  'ding': 2439,
#  'fassyole': 2892,
#  'blacko': 1435,
#  'londn': 4388,
#  'ic': 3725,
#  'mary': 4571,
#  'jane': 3954,
#  'able': 811,
#  'den': 2352,
#  'shld': 6387,
#  'gee': 3205,
#  'nvm': 5115,
#  'kaiez': 4047,
#  'jazz': 3965,
#  'scared': 6221,
#  'hiphop': 3559,
#  'open': 5218,
#  'deduct': 2322,
#  'food': 3036,
#  'elaborating': 2674,
#  'safety': 6161,
#  'aspects': 1170,
#  'issues': 3907,
#  'shes': 6364,
#  'studying': 6851,
#  'warwick': 7708,
#  'weve': 7790,
#  'planned': 5506,
#  'concert': 2043,
#  'tmw': 7244,
#  'may': 4598,
#  'canceled': 1708,
#  'havnt': 3475,
#  'seen': 6276,
#  'sometime': 6599,
#  'thinked': 7161,
#  'saw': 6210,
#  'class': 1919,
#  'fret': 3109,
#  'ovulation': 5295,
#  'test': 7092,
#  'strips': 6835,
#  'march': 4557,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8151 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
# Can we convert to vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())
# Out:
# G:\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# G:\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# G:\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.794 / Accuracy: 0.97
